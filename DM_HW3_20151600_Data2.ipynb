# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Wine dataset 불러오기

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

iris = load_iris()
X_train, X_test, Y_train, Y_test = train_test_split(iris.data, iris.target, random_state=777, test_size=0.2)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (120, 4)
# (30, 4)
# (120,)
# (30,)

# %% [markdown]
# # Wine dataset (참고용)

# %%
df = pd.DataFrame(iris.data, columns=iris.feature_names)
sy = pd.Series(iris.target, dtype="category")
sy = sy.cat.rename_categories(iris.target_names)
df['class'] = sy
print(digit.DESCR)
df.head()
# Out:
# .. _digits_dataset:
#
# Optical recognition of handwritten digits dataset
# --------------------------------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 5620
#     :Number of Attributes: 64
#     :Attribute Information: 8x8 image of integer pixels in the range 0..16.
#     :Missing Attribute Values: None
#     :Creator: E. Alpaydin (alpaydin '@' boun.edu.tr)
#     :Date: July; 1998
#
# This is a copy of the test set of the UCI ML hand-written digits datasets
# https://archive.ics.uci.edu/ml/datasets/Optical+Recognition+of+Handwritten+Digits
#
# The data set contains images of hand-written digits: 10 classes where
# each class refers to a digit.
#
# Preprocessing programs made available by NIST were used to extract
# normalized bitmaps of handwritten digits from a preprinted form. From a
# total of 43 people, 30 contributed to the training set and different 13
# to the test set. 32x32 bitmaps are divided into nonoverlapping blocks of
# 4x4 and the number of on pixels are counted in each block. This generates
# an input matrix of 8x8 where each element is an integer in the range
# 0..16. This reduces dimensionality and gives invariance to small
# distortions.
#
# For info on NIST preprocessing routines, see M. D. Garris, J. L. Blue, G.
# T. Candela, D. L. Dimmick, J. Geist, P. J. Grother, S. A. Janet, and C.
# L. Wilson, NIST Form-Based Handprint Recognition System, NISTIR 5469,
# 1994.
#
# .. topic:: References
#
#   - C. Kaynak (1995) Methods of Combining Multiple Classifiers and Their
#     Applications to Handwritten Digit Recognition, MSc Thesis, Institute of
#     Graduate Studies in Science and Engineering, Bogazici University.
#   - E. Alpaydin, C. Kaynak (1998) Cascading Classifiers, Kybernetika.
#   - Ken Tang and Ponnuthurai N. Suganthan and Xi Yao and A. Kai Qin.
#     Linear dimensionalityreduction using relevance weighted LDA. School of
#     Electrical and Electronic Engineering Nanyang Technological University.
#     2005.
#   - Claudio Gentile. A New Approximate Maximal Margin Classification
#     Algorithm. NIPS. 2000.
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)   class
# 0                5.1               3.5  ...               0.2  setosa
# 1                4.9               3.0  ...               0.2  setosa
# 2                4.7               3.2  ...               0.2  setosa
# 3                4.6               3.1  ...               0.2  setosa
# 4                5.0               3.6  ...               0.2  setosa
#
# [5 rows x 5 columns]

# %% [markdown]
# # # Problem 1
# ID3 Decision Tree classifier.
# - decision-tree-id3 패키지를 pip install을 통해 설치하시오.
# - 위의 train 데이터(X_train, Y_train)를 이용하여 ID3 classifier 모델을 학습시키시오.
# - 위의 test 데이터(X_test, Y_test)를 이용해 정확도를 측정 후 출력하시오.

# %%
##########Put your installation code here###############
# !pip install decision-tree-id3
########################################################
# Out:
# Collecting decision-tree-id3
#   Downloading https://files.pythonhosted.org/packages/53/60/9b51eb3b5096afa1fce2718f56c99f8e183162dae114c56592112ab54329/decision-tree-id3-0.1.2.tar.gz
# Collecting nose>=1.1.2
#   Downloading https://files.pythonhosted.org/packages/15/d8/dd071918c040f50fa1cf80da16423af51ff8ce4a0f2399b7bf8de45ac3d9/nose-1.3.7-py3-none-any.whl (154kB)
#      |████████████████████████████████| 163kB 6.9MB/s
# Requirement already satisfied: scikit-learn>=0.17 in /usr/local/lib/python3.6/dist-packages (from decision-tree-id3) (0.22.2.post1)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from decision-tree-id3) (1.18.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.17->decision-tree-id3) (0.14.1)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.17->decision-tree-id3) (1.4.1)
# Building wheels for collected packages: decision-tree-id3
#   Building wheel for decision-tree-id3 (setup.py) ... done
#   Created wheel for decision-tree-id3: filename=decision_tree_id3-0.1.2-cp36-none-any.whl size=15962 sha256=57bce0ed4164f4ac83e0c9f6c766d8cd8c27eac9f0abeddb3b3f0c9fa80c085c
#   Stored in directory: /root/.cache/pip/wheels/2d/d6/f2/96cb2cc307503a88b1235aef5c794990e460bd044f382070f9
# Successfully built decision-tree-id3
# Installing collected packages: nose, decision-tree-id3
# Successfully installed decision-tree-id3-0.1.2 nose-1.3.7

# %%
from id3 import Id3Estimator

ID3_model = None
accuracy = None
############# Put your code here ################
ID3_model = Id3Estimator()
ID3_model.fit(X_train, Y_train)
test=ID3_model.predict(X_test)
accuracy=0;
per=1/len(test)
for i in range(len(test)):
  if test[i]==Y_test[i]:
    accuracy+=per
################################################# 
print('Test data prediction accuracy (ID3) : %f'%accuracy)
# Out:
# Test data prediction accuracy (ID3) : 0.966667
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)

# %% [markdown]
# # # Problem 2
# CART decision Tree classifier.
# - scikit-learn의 decision tree는 CART 기반 구현체이다.
# - Problem 1과 같은 방법으로 CART classifier 모델을 학습시키고 test데이터의 정확도를 출력하시오.

# %%
from sklearn.tree import DecisionTreeClassifier

CART_model = None
accuracy = None
############# Put your code here ################
CART_model = DecisionTreeClassifier(random_state=0)
CART_model.fit(X_train, Y_train)
accuracy=CART_model.score(X_test, Y_test)
################################################# 
print('Test data prediction accuracy (CART) : %f'%accuracy)
# Out:
# Test data prediction accuracy (CART) : 0.900000

# %% [markdown]
# # # Problem 3
# Random Forest classifier.
# - scikit-learn의 random forest 패키지를 이용하여 모델을 학습시키고 test데이터의 정확도를 출력하시오.

# %%
from sklearn.ensemble import RandomForestClassifier

Random_Forest_model = None
accuracy = None
############# Put your code here ################
Random_Forest_model = RandomForestClassifier(random_state=0)
Random_Forest_model.fit(X_train,Y_train)
accuracy=Random_Forest_model.score(X_test, Y_test)
################################################# 
print('Test data prediction accuracy (Random Forest) : %f'%accuracy)
# Out:
# Test data prediction accuracy (Random Forest) : 0.933333

# %% [markdown]
# # # Problem 4
# XGBoost classifier.
# - XGBoost 패키지를 pip install을 통해 설치하시오.
# - 패키지를 불러와 모델을 학습시키고 test데이터의 정확도를 출력하시오.

# %%
##########Put your installation code here###############
# !pip install XGBoost
########################################################
# Out:
# Requirement already satisfied: XGBoost in /usr/local/lib/python3.6/dist-packages (0.90)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from XGBoost) (1.18.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from XGBoost) (1.4.1)

# %%
import xgboost as xgb

XGB_model = None
accuracy = None
############# Put your code here ################
XGB_model = xgb.XGBClassifier()
XGB_model.fit(X_train, Y_train)
test=XGB_model.predict(X_test)
accuracy=0;
per=1/len(test)
for i in range(len(test)):
  if test[i]==Y_test[i]:
    accuracy+=per
################################################# 
print('Test data prediction accuracy (XGBoost) : %f'%accuracy)
# Out:
# Test data prediction accuracy (XGBoost) : 0.966667

# %% [markdown]
# # # Problem 5
# LightGBM classifier.
# - LighGBM 패키지를 pip install을 통해 설치하시오.
# - 패키지를 불러와 모델을 학습시키고 test데이터의 정확도를 출력하시오.

# %%
##########Put your installation code here###############
# !pip install LightGBM
########################################################
# Out:
# Requirement already satisfied: LightGBM in /usr/local/lib/python3.6/dist-packages (2.2.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from LightGBM) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from LightGBM) (1.18.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from LightGBM) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->LightGBM) (0.14.1)

# %%
import lightgbm as lgb

LGBM_model = None
accuracy = None
############# Put your code here ################
LGBM_model = lgb.LGBMClassifier(n_estimators=200)
LGBM_model.fit(X_train,Y_train,early_stopping_rounds=100,eval_metric="logloss",eval_set=[(X_test,Y_test)],verbose= True )
test = LGBM_model.predict(X_test)
accuracy=0;
per=1/len(test)
for i in range(len(test)):
  if test[i]==Y_test[i]:
    accuracy+=per
################################################# 
print('Test data prediction accuracy (LightGBM) : %f'%accuracy)
# Out:
# [1]	valid_0's multi_logloss: 0.999948	valid_0's multi_logloss: 0.999948
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's multi_logloss: 0.888603	valid_0's multi_logloss: 0.888603
# [3]	valid_0's multi_logloss: 0.801197	valid_0's multi_logloss: 0.801197
# [4]	valid_0's multi_logloss: 0.721911	valid_0's multi_logloss: 0.721911
# [5]	valid_0's multi_logloss: 0.657665	valid_0's multi_logloss: 0.657665
# [6]	valid_0's multi_logloss: 0.595141	valid_0's multi_logloss: 0.595141
# [7]	valid_0's multi_logloss: 0.545101	valid_0's multi_logloss: 0.545101
# [8]	valid_0's multi_logloss: 0.498882	valid_0's multi_logloss: 0.498882
# [9]	valid_0's multi_logloss: 0.455793	valid_0's multi_logloss: 0.455793
# [10]	valid_0's multi_logloss: 0.421722	valid_0's multi_logloss: 0.421722
# [11]	valid_0's multi_logloss: 0.389536	valid_0's multi_logloss: 0.389536
# [12]	valid_0's multi_logloss: 0.363138	valid_0's multi_logloss: 0.363138
# [13]	valid_0's multi_logloss: 0.335286	valid_0's multi_logloss: 0.335286
# [123]	valid_0's multi_logloss: 0.0936364	valid_0's multi_logloss: 0.0936364
# [124]	valid_0's multi_logloss: 0.0936621	valid_0's multi_logloss: 0.0936621
# [125]	valid_0's multi_logloss: 0.0931172	valid_0's multi_logloss: 0.0931172
# [126]	valid_0's multi_logloss: 0.0932813	valid_0's multi_logloss: 0.0932813
# [127]	valid_0's multi_logloss: 0.0958953	valid_0's multi_logloss: 0.0958953
# [128]	valid_0's multi_logloss: 0.0958716	valid_0's multi_logloss: 0.0958716
# [129]	valid_0's multi_logloss: 0.0977036	valid_0's multi_logloss: 0.0977036
# [130]	valid_0's multi_logloss: 0.0976872	valid_0's multi_logloss: 0.0976872
# [131]	valid_0's multi_logloss: 0.0981092	valid_0's multi_logloss: 0.0981092
# [132]	valid_0's multi_logloss: 0.098183	valid_0's multi_logloss: 0.098183
# [133]	valid_0's multi_logloss: 0.100879	valid_0's multi_logloss: 0.100879
# [134]	valid_0's multi_logloss: 0.100865	valid_0's multi_logloss: 0.100865
# [135]	valid_0's multi_logloss: 0.10272	valid_0's multi_logloss: 0.10272
# [136]	valid_0's multi_logloss: 0.100907	valid_0's multi_logloss: 0.100907
# [137]	valid_0's multi_logloss: 0.101161	valid_0's multi_logloss: 0.101161
# [138]	valid_0's multi_logloss: 0.100201	valid_0's multi_logloss: 0.100201
# [139]	valid_0's multi_logloss: 0.100285	valid_0's multi_logloss: 0.100285
# [140]	valid_0's multi_logloss: 0.10308	valid_0's multi_logloss: 0.10308
# [141]	valid_0's multi_logloss: 0.103187	valid_0's multi_logloss: 0.103187
# [142]	valid_0's multi_logloss: 0.104101	valid_0's multi_logloss: 0.104101
# [143]	valid_0's multi_logloss: 0.105604	valid_0's multi_logloss: 0.105604
# [144]	valid_0's multi_logloss: 0.105599	valid_0's multi_logloss: 0.105599
# [145]	valid_0's multi_logloss: 0.107541	valid_0's multi_logloss: 0.107541
# [146]	valid_0's multi_logloss: 0.110374	valid_0's multi_logloss: 0.110374
# [147]	valid_0's multi_logloss: 0.110556	valid_0's multi_logloss: 0.110556
# [148]	valid_0's multi_logloss: 0.110549	valid_0's multi_logloss: 0.110549
# [149]	valid_0's multi_logloss: 0.113491	valid_0's multi_logloss: 0.113491
# [150]	valid_0's multi_logloss: 0.114122	valid_0's multi_logloss: 0.114122
# [151]	valid_0's multi_logloss: 0.11411	valid_0's multi_logloss: 0.11411
# [152]	valid_0's multi_logloss: 0.113061	valid_0's multi_logloss: 0.113061
# [153]	valid_0's multi_logloss: 0.113245	valid_0's multi_logloss: 0.113245
# [154]	valid_0's multi_logloss: 0.116245	valid_0's multi_logloss: 0.116245
# [155]	valid_0's multi_logloss: 0.11624	valid_0's multi_logloss: 0.11624
# [156]	valid_0's multi_logloss: 0.118234	valid_0's multi_logloss: 0.118234
# [157]	valid_0's multi_logloss: 0.118393	valid_0's multi_logloss: 0.118393
# [158]	valid_0's multi_logloss: 0.118667	valid_0's multi_logloss: 0.118667
# [159]	valid_0's multi_logloss: 0.121747	valid_0's multi_logloss: 0.121747
# [160]	valid_0's multi_logloss: 0.121894	valid_0's multi_logloss: 0.121894
# [161]	valid_0's multi_logloss: 0.122809	valid_0's multi_logloss: 0.122809
# [162]	valid_0's multi_logloss: 0.123145	valid_0's multi_logloss: 0.123145
# [163]	valid_0's multi_logloss: 0.124118	valid_0's multi_logloss: 0.124118
# [164]	valid_0's multi_logloss: 0.124382	valid_0's multi_logloss: 0.124382
# [165]	valid_0's multi_logloss: 0.127555	valid_0's multi_logloss: 0.127555
# [166]	valid_0's multi_logloss: 0.127547	valid_0's multi_logloss: 0.127547
# [167]	valid_0's multi_logloss: 0.129585	valid_0's multi_logloss: 0.129585
# [168]	valid_0's multi_logloss: 0.129811	valid_0's multi_logloss: 0.129811
# [169]	valid_0's multi_logloss: 0.130151	valid_0's multi_logloss: 0.130151
# [170]	valid_0's multi_logloss: 0.133371	valid_0's multi_logloss: 0.133371
# [171]	valid_0's multi_logloss: 0.133362	valid_0's multi_logloss: 0.133362
# [172]	valid_0's multi_logloss: 0.133788	valid_0's multi_logloss: 0.133788
# [173]	valid_0's multi_logloss: 0.134098	valid_0's multi_logloss: 0.134098
# [174]	valid_0's multi_logloss: 0.137302	valid_0's multi_logloss: 0.137302
# Early stopping, best iteration is:
# [74]	valid_0's multi_logloss: 0.064711	valid_0's multi_logloss: 0.064711
# Test data prediction accuracy (LightGBM) : 0.966667

# %% [markdown]
# # # Problem 6
# Naive Bayes classifier.
# - Scikit-learn의 Gaussian Naive Bayes classifier를 불러와 학습시키고, test데이터의 정확도를 출력하시오.

# %%
from sklearn.naive_bayes import GaussianNB

NB_model = None
accuracy = None
############# Put your code here ################
NB_model = GaussianNB()
NB_model.fit(X_train, Y_train)
test = NB_model.predict(X_test)
accuracy=0;
per=1/len(test)
for i in range(len(test)):
  if test[i]==Y_test[i]:
    accuracy+=per       
################################################# 
print('Test data prediction accuracy (NaiveBayes) : %f'%accuracy)
# Out:
# Test data prediction accuracy (NaiveBayes) : 0.966667

# %% [markdown]
# # # Problem 7
# Ensemble classifier.
# - 위의 6개의 모델(ID3, CART, Random Forest, XGBoost, LightGBM, Naive Bayes)을 이용하여 Voting(6개의 예측 label중 가장 많이 예측된 label을 최종 prediction label로 택하는것)방법으로 최종 label을 택한 뒤, 예측 정확도를 출력하시오.
# - Scikit-learn의 VotingClassifier 패키지를 사용하여 작성.
# - 위에서 학습시킨 모델 변수명 사용 가능.

# %%
from sklearn.ensemble import VotingClassifier

ensemble_classifier = None
accuracy = None
############# Put your code here ################
ensemble_classifier = VotingClassifier([
                       # ('ID3',ID3_model),
                        ('CART', DecisionTreeClassifier(random_state=0)),
                        ('Random Forest', RandomForestClassifier(random_state=0)),
                        ('XGBoost',xgb.XGBClassifier()),
                        ('LightGBM',lgb.LGBMClassifier(n_estimators=200)),
                        ('Naive Bayes',GaussianNB())
                        ])

ensemble_classifier.fit(X_train,Y_train);
accuracy=ensemble_classifier.score(X_test, Y_test)
################################################# 
print('Test data prediction accuracy (Ensemble) : %f'%accuracy)
# Out:
# Test data prediction accuracy (Ensemble) : 0.966667
